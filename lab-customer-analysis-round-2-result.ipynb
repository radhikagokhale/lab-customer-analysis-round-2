# %%
import pandas as pd
import numpy as np

# %%
#1. Show the dataframe shape.
#2. Standardize header names.

df1 = pd.read_csv(r'C:\Users\parag\Desktop\ironhack\lab\week2\lab-customer-analysis-round-2\files_for_lab\csv_files\marketing_customer_analysis.csv')
cols = [col_name.lower().replace(' ', '_') for col_name in df1.columns]
df1.columns=cols
df1.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type'],
#       dtype='object')

# %%
df1.shape
# Out:
# (10910, 26)

# %%
df1.dtypes
# Out:
# unnamed:_0                         int64
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# ...

# %%
#3. Which columns are numerical?
numerics = ['int16', 'int32', 'int64']
df = df1.select_dtypes(include=numerics)
df
# Out:
#        unnamed:_0  income  monthly_premium_auto  \
# 0               0   48029                    61
# 1               1       0                    64
# 2               2   22139                   100
# 3               3   49078                    97
# 4               4   23675                   117
# ...           ...     ...                   ...
# 10905       10905       0                   253
# 10906       10906   61146                    65
# 10907       10907   39837                   201
# 10908       10908   64195                   158
# 10909       10909       0                   101
#
#        months_since_policy_inception  number_of_policies
# 0                                 52                   9
# 1                                 26                   1
# 2                                 31                   2
# 3                                  3                   2
# 4                                 31                   7
# ...

# %%
#df1['gender'].value_counts()
df1.head(20)
# Out:
#     unnamed:_0 customer       state  customer_lifetime_value response  \
# 0            0  DK49336     Arizona              4809.216960       No
# 1            1  KX64629  California              2228.525238       No
# 2            2  LZ68649  Washington             14947.917300       No
# 3            3  XL78013      Oregon             22332.439460      Yes
# 4            4  QA50777      Oregon              9025.067525       No
# 5            5  HO81102         NaN              4745.181764      NaN
# 6            6  IW72280  California              5035.035257       No
# 7            7  IH64929  California              4956.247235       No
# 8            8  FM55990  California              5989.773931      Yes
# 9            9  QX31376      Oregon             17114.328150       No
# 10          10  HG93801     Arizona              5154.764074       No
# 11          11  GE63585         NaN              2420.711888      NaN
# ...

# %%
#4. Which columns are categorical?
df1['state'].value_counts()
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: state, dtype: int64

# %%
df1['gender'].value_counts()
# Out:
# F    5573
# M    5337
# Name: gender, dtype: int64

# %%
df1.select_dtypes(include=np.object).columns.tolist()
# Out:
# C:\Users\parag\AppData\Local\Temp/ipykernel_5188/2834833298.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df1.select_dtypes(include=np.object).columns.tolist()
# ['customer',
#  'state',
#  'response',
#  'coverage',
#  'education',
#  'effective_to_date',
#  'employmentstatus',
#  'gender',
#  'location_code',
#  'marital_status',
#  'policy_type',
#  'policy',
#  'renew_offer_type',
#  'sales_channel',
#  'vehicle_class',
#  'vehicle_size',
#  'vehicle_type']

# %%
# 5. Check and deal with `NaN` values.
pd.set_option('display.max_columns',500)
df1.isna().sum()
df1[df1.['state'].isna()]
# Out:
#   File "C:\Users\parag\AppData\Local\Temp/ipykernel_5188/2152083239.py", line 4
#     df1[df1.['state'].isna()]
#             ^
# SyntaxError: invalid syntax

# %%
df1.dropna(thresh=2,inplace=True)
df1
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
#drop columns
df1.dropna(how='any',subset=['state', 'response','months_since_last_claim','number_of_open_complaints','vehicle_class','vehicle_size'], inplace=True)

# %%
#drop 'vehicle type' column as about it have Nan values
df1=df1.iloc[:,:25]
df1.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
#6. Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. _Hint_: If data from March does not exist, consider only January and February.
#pd.DatetimeIndex(df['effective_to_date']).year
    
from datetime import datetime

# We are going to provide the date format to the dates.
df1['effective_to_date']=pd.to_datetime(df1['effective_to_date'],format="%m/%d/%Y")

# Now we are going to extract the month to another column.

#df1['month'] = pd.DatetimeIndex(df1['effective_to_date']).month
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     508         try:
# --> 509             values, tz = conversion.datetime_to_datetime64(arg)
#     510             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5188/3440194703.py in <module>
#       5
#       6 # We are going to provide the date format to the dates.
# ...

# %%
# Now we will generate a definitive dataframe just including the observations from January and February 
# (as there is none from March)
df1=df1[(df1['month']==1)|(df1['month']==2)|(df1['month']==3)]
df1['month'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
